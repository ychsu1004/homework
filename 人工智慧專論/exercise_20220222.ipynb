# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 5, 50)

# %%
y = 1.2 * x + 0.8

# %%
plt.scatter(x,y)
plt.plot(x, y, 'r')

# %%
y = 1.2 * x + 0.8 + 0.6 * np.random.randn(50)

# %%
plt.scatter(x, y)
plt.plot(x, 1.2 * x + 0.8, 'r')

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
y
# Out:
# array([-0.909349  ,  0.5781002 , -0.1591555 ,  1.28296644,  0.53991926,
#         1.71963859,  2.10481626,  1.68279746,  2.13300748,  1.83703275,
#         3.74772394,  1.98135834,  2.97578138,  1.60918284,  2.56742701,
#         3.81648243,  2.40363566,  3.77293877,  2.78851184,  2.5418106 ,
#         3.26024714,  4.04567847,  3.99764836,  4.59607999,  3.33842054,
#         3.1116935 ,  5.33550949,  4.97623858,  4.27327466,  4.88194995,
#         4.78532999,  3.40771829,  3.60557888,  5.05069688,  4.94990562,
#         5.71878685,  4.08889688,  5.74403745,  5.72051224,  5.29328333,
#         5.13107373,  5.05838982,  4.81328914,  5.57177508,  7.29953906,
#         5.92280068,  5.84141193,  5.64606415,  7.8529337 ,  6.60162716])

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
#開一台線性回歸機機器
regr = LinearRegression()

# %%
X = x.reshape(50,1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, Y, 'r')
plt.plot(x, 1.2*x+0.8, 'g')
