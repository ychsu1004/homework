# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 50)

# %%
y = 1.2 * x + 0.8

# %%
plt.scatter(x, y)
plt.plot(x, y, 'r')

# %%
y = 1.2 * x + 0.8 + 0.6 * np.random.randn(50)

# %%
plt.scatter(x, y)
plt.plot(x, 1.2*x+0.8, 'r')

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
y
# Out:
# array([-0.01733303,  1.07988283,  1.59303051,  1.21110833,  0.31152611,
#         1.24082109,  0.91922197,  0.0492467 ,  1.45495392,  1.2858095 ,
#         1.99786758,  2.5149974 ,  1.98452057,  2.25876522,  2.1091322 ,
#         2.91471292,  3.01364052,  2.93336467,  2.67542137,  3.74882858,
#         3.43754702,  2.96522311,  3.21654457,  5.32708701,  4.96007276,
#         3.94334378,  3.90256831,  3.94305776,  3.92797384,  3.69465754,
#         4.79569899,  4.02762144,  3.8546215 ,  4.93632155,  5.15916857,
#         5.66237889,  5.7346798 ,  4.87764281,  5.7302658 ,  5.44338975,
#         5.62136609,  5.74546834,  5.87288333,  6.11187509,  6.32611279,
#         5.09499265,  6.40904094,  6.95365524,  5.91372311,  7.55510124])

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = c()

# %%
X = x.reshape(50, 1)

# %%
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, Y, 'r')
plt.plot(x, 1.2*x+0.8, 'g')

# %%
x = np.linspace(0, 5, 100)
y = 1.2*x + 0.8 + 0.5*np.random.randn(100)

# %%
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                   test_size=0.2,
                                                   random_state=87)

# %%
x_train = x_train.reshape(80,1)

# %%
x_test.shape = (20,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = regr.predict(x_train)

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, pred, 'r')

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, regr.predict(x_test), 'r')
